# %%
import tabula
import pandas as pd
import re

# suppress SettingWithCopyWarning
pd.options.mode.chained_assignment = None

# %%
### UNCOMMENT TO RIP A SINGLE FILE ON DEMAND

# file_path = "pdfs/Cherrybrook_Technology_High_School.pdf"

# %%
# read all pages of pdf; return list of dfs

df_list = tabula.read_pdf(file_path, pages = "all")

# %%
df_list[2]
# Out:
#    B00A - R0001 - Computer Learning Space - (60.32 SQM) - Teaching Space: 1  \
# 0   B00A - R0008 - Computer Learning Space - (60.3...
# 1   B00A - R0014 - General Learning Space - (57.91...
# 2   B00A - R0015 - General Learning Space - (58.23...
# 3   B00A - R0016 - General Learning Space - (57.96...
# 4   B00A - R0018 - General Learning Space - (63.43...
# 5   B00A - R0019 - General Learning Space - (63.34...
# 6   B00A - R0021 - General Learning Space - (58.22...
# 7   B00A - R0022 - General Learning Space - (57.9 ...
# 8   B00A - R0023 - General Learning Space - (58.13...
# 9   B00A - R0026 - General Learning Space - (66.32...
# 10      B00A - R0028 - Seminar - Type 1 - (27.92 SQM)
# 11              B00A - R0031 - Movement - (30.01 SQM)
# 12      B00A - R0034 - Seminar - Type 1 - (27.92 SQM)
# 13  B00A - R0037 - General Learning Space - (66.15...
# 14               B00A - R0038 - Movement - (9.22 SQM)
# 15  B00A - R0039 - Shared Learning Space - (71.99 ...
# 16              B00A - R0040 - Movement - (14.32 SQM)
# 17              B00A - R0041 - Movement - (14.22 SQM)
# 18  B00A - R0042 - Computer Learning Space - (71.9...
# 19               B00A - R0043 - Movement - (9.45 SQM)
# 20          B00A - R9001 - Public Entry - (17.19 SQM)
# 21      B00A - R9013 - Principal Office - (24.36 SQM)
# 22     B00A - R9020 - Interview/Meeting - (16.95 SQM)
# 23     B00A - R9021 - Interview/Meeting - (13.98 SQM)
# 24              B00A - R9023 - Movement - (33.08 SQM)
# 25                B00A - R9026 - Clinic - (13.21 SQM)
# 26  B00A - R9027 - Interview/Office - Type 1 - (13...
# 27  B00A - R9028 - Interview/Office - Type 1 - (12...
# 28  B00A - R9030 - Interview/Office - Type 1 - (13...
# 29  B00A - R9031 - Interview/Office - Type 1 - (13...
# 30              B00A - R9032 - Tea Room - (12.74 SQM)
# 31  B00A - R9046 - General Learning Space - (58.77...
# 32  B00A - R9048 - Administration - Clerical - (10...
# 33               B00A - R9049 - Movement - (71.6 SQM)
# 34  B00A - R9050 - Administration - Executive - (1...
# 35  B00A - R9051 - Interview/Office - Type 1 - (12...
# 36  B00A - R9052 - Deputy Principal Office - (13.7...
# 37     B00A - R9053 - Interview/Meeting - (34.11 SQM)
# 38          B00A - R9055 - Staff Study - (109.18 SQM)
# 39               B00A - R9056 - Tea Room - (6.07 SQM)
# 40       B00A - R9058 - Ancillary Staff - (16.77 SQM)
# 41      B00A - R9062 - Public Reception - (37.12 SQM)
# 42  B00A - R9064 - Deputy Principal Office - (14.1...
# 43  B00A - R9065 - Deputy Principal Office - (17.6...
# 44  B00A - R9068 - General Learning Space - (66.31...
# 45  B00A - R9069 - Administration - Executive - (1...
# 46      B00A - R9070 - Seminar - Type 1 - (14.03 SQM)
#
#     Student Space (27)                     Unnamed: 0
# 0   Student Space (27)                            NaN
# 1   Student Space (26)                            NaN
# 2   Student Space (27)                            NaN
# 3   Student Space (26)                            NaN
# 4   Student Space (29)                            NaN
# 5   Student Space (29)                            NaN
# 6   Student Space (27)                            NaN
# 7   Student Space (26)                            NaN
# 8   Student Space (26)                            NaN
# 9   Student Space (30)                            NaN
# 10          Office (6)                            NaN
# 11      Not Applicable  Circulation or storage space.
# 12          Office (6)                            NaN
# 13  Student Space (30)                            NaN
# 14      Not Applicable  Circulation or storage space.
# 15  Student Space (33)                            NaN
# 16      Not Applicable  Circulation or storage space.
# 17      Not Applicable  Circulation or storage space.
# 18  Student Space (33)                            NaN
# 19      Not Applicable  Circulation or storage space.
# 20      Not Applicable  Circulation or storage space.
# 21          Office (6)                            NaN
# 22          Office (4)                            NaN
# 23          Office (3)                            NaN
# 24      Not Applicable  Circulation or storage space.
# 25          Office (3)                            NaN
# 26          Office (3)                            NaN
# 27          Office (3)                            NaN
# 28          Office (3)                            NaN
# 29          Office (3)                            NaN
# 30      Not Applicable  Circulation or storage space.
# 31  Student Space (27)                            NaN
# 32         Office (27)                            NaN
# 33      Not Applicable  Circulation or storage space.
# 34          Office (3)                            NaN
# 35          Office (3)                            NaN
# 36          Office (3)                            NaN
# 37          Office (8)                            NaN
# 38         Office (27)                            NaN
# 39      Not Applicable  Circulation or storage space.
# 40          Office (4)                            NaN
# 41      Not Applicable  Circulation or storage space.
# 42          Office (3)                            NaN
# 43          Office (4)                            NaN
# 44  Student Space (30)                            NaN
# 45          Office (2)                            NaN
# 46          Office (3)                            NaN

# %%
# take just the dfs containing room data
# process each one, adding accuracy stats to overall total

num_pages = len(df_list)

# iterate from df 2 onwards
# df 0 and 1 are always intro pages and are discarded
for i in range(2, num_pages):
    df_rooms = df_list[i]
    # %run process_one_table.ipynb
    school_name = file_path.replace("pdfs/", "").replace(".pdf", "")
    # name the tables from 1 onwards
    df_catA.to_csv("outputs/" + school_name + str(i-1) + ".csv")
    
df_catA
# Out:
# Num Spaces =		48
# Num Cat A spaces =	16
# Num Spaces =		50
# Num Cat A spaces =	21
# Num Spaces =		47
# Num Cat A spaces =	26
# Num Spaces =		46
# Num Cat A spaces =	31
# Num Spaces =		13
# Num Cat A spaces =	4
#                                                 room            category  \
# 4  NS 270 13187 - NS 270 13187 - Metal Technics/H...  Student Space (44)
# 5  OS 600 13406 - OS 600 13406 - Learning Unit - ...  Student Space (26)
# 6  OS 600 14882 - OS 600 14882 - Learning Unit - ...  Student Space (26)
# 7  OS 600 15889 - OS 600 15889 - Learning Unit - ...  Student Space (26)
#
#    area  capacity  capacity_guess  delta
# 4  95.0        44              43      1
# 5  57.0        26              26      0
# 6  57.0        26              26      0
# 7  57.0        26              26      0
